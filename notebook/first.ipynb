# %%
from president_speech.db.parquet_interpreter import read_parquet, get_parquet_full_path

# %%
data_path = get_parquet_full_path()

# %%
import pandas as pd

# %%
df = pd.read_parquet(data_path)

# %%
df.head()
# Out:
#       division_number president                title        date location  \
# 5368          1305368       박정희  제5대 대통령 취임식 대통령 취임사  1963.12.17       국내
# 5369          1305369       박정희            국회 개회식 치사  1963.12.17       국내
# 5370          1305370       박정희               신년 메시지  1964.01.01       국내
# 5371          1305371       박정희      신년 시무식에 즈음한 담화문        1964       국내
# 5372          1305372       박정희       고급공무원에게 보내는 서신  1964.01.04       국내
#
#         kind                                        speech_text
# 5368     취임사  \n\n\n단군성조가 천혜의 이 강토 위에 국기를 닦으신지 반만년, 연면히 이어온 ...
# 5369     기념사   존경하는 국회의장, 의원제위 그리고 내외귀빈 여러분! 오늘 이 뜻깊은 제3공화국의...
# 5370     신년사   친애하는 국내외의 동포 여러분! 혁명의 고된 시련을 겪고 민정이양으로 매듭을 지은...
# 5371  성명/담화문  친애하는 전국의 공무원 여러분! 민족 역사 위에 격동과 시련의 해로 길이 기록될 계...
# 5372     기념사  청 감갑진년의 새아침을 맞이하여 귀하와 귀하의 가정에 만복이 깃들기를 빌며, 새해에...

# %%
df.tail()
# Out:
#         division_number president      title        date location kind  \
# 102587          1401987       문재인   수석·보좌관회의  2021.04.05       국내   회의
# 102588          1401988       문재인  제16회 국무회의  2021.04.13       국내   회의
# 102589          1401989       문재인   수석·보좌관회의  2021.04.19       국내   회의
# 102590          1401990       문재인   수석·보좌관회의  2021.04.26       국내   회의
# 102591          1401991       문재인  제18회 국무회의  2021.04.27       국내   회의
#
#                                               speech_text
# 102587  우리가 코로나19 이전으로 얼마나 빨리 돌아갈 수 있는지 여부는 오로지 방역과 백신...
# 102588  정부는 국민께 무한책임을 진다는 자세로 흔들림 없이 국정에 임해야 합니다.방역도, ...
# 102589  우리 정부 임기 마지막 날까지 흔들림 없이 국민과 역사가 부여한 책무를 다하자는 다...
# 102590  코로나19와 같은 감염병의 세계적 대유행은 어느 한 나라가 자국의 문제를 해결한다고...
# 102591  오늘 한국은행이 발표한 1분기 GDP 속보치에 따르면 우리 경제는 올해 1분기에 이...

# %%
df.values[1:3]
# Out:
# array([[1305369, '박정희', '국회 개회식 치사', '1963.12.17', '국내', '기념사',
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['division_number', 'president', 'title', 'date', 'location', 'kind',
#        'speech_text'],
#       dtype='object')

# %%
df.describe()
# Out:
#        division_number
# count     8.771000e+03
# mean      1.330350e+06
# std       3.749870e+04
# min       1.305368e+06
# 25%       1.307560e+06
# 50%       1.309753e+06
# 75%       1.330362e+06
# max       1.401991e+06

# %%
df.T
# Out:
#                                                             5368    \
# division_number                                            1305368
# president                                                      박정희
# title                                          제5대 대통령 취임식 대통령 취임사
# date                                                    1963.12.17
# location                                                        국내
# kind                                                           취임사
# speech_text      \n\n\n단군성조가 천혜의 이 강토 위에 국기를 닦으신지 반만년, 연면히 이어온 ...
#
#                                                             5369    \
# division_number                                            1305369
# president                                                      박정희
# title                                                    국회 개회식 치사
# date                                                    1963.12.17
# location                                                        국내
# ...

# %%
df
# Out:
#         division_number president                title        date location  \
# 5368            1305368       박정희  제5대 대통령 취임식 대통령 취임사  1963.12.17       국내
# 5369            1305369       박정희            국회 개회식 치사  1963.12.17       국내
# 5370            1305370       박정희               신년 메시지  1964.01.01       국내
# 5371            1305371       박정희      신년 시무식에 즈음한 담화문        1964       국내
# 5372            1305372       박정희       고급공무원에게 보내는 서신  1964.01.04       국내
# ...                 ...       ...                  ...         ...      ...
# 102587          1401987       문재인             수석·보좌관회의  2021.04.05       국내
# 102588          1401988       문재인            제16회 국무회의  2021.04.13       국내
# 102589          1401989       문재인             수석·보좌관회의  2021.04.19       국내
# 102590          1401990       문재인             수석·보좌관회의  2021.04.26       국내
# 102591          1401991       문재인            제18회 국무회의  2021.04.27       국내
#
# ...

# %%
df.sort_values(by='president').head(3)
# Out:
#       division_number president  \
# 8763          1308731       김대중
# 8941          1308909       김대중
# 8942          1308910       김대중
#
#                                               title        date location kind  \
# 8763    새천년준비위원 위촉장 수여 및 오찬 말씀(새천년에 가장 중요한 것은 의식개혁)  1999.04.12       국내  기념사
# 8941          제78회 어린이날 축하 메시지(꿈을 가진 사람만이 내일을 만듭니다)  2000.05.05       국내  기념사
# 8942  알레만 니카라과 대통령 내외를 위한 만찬연설(니카라과는 새천년 공동번영의 동반자)  2000.05.15       국내  환영사
#
#                                             speech_text
# 8763  여러분께서 이번에 새천년을 앞두고 우리의 운명을 생각하는 막중한 대임을 맡게 되었습...
# 8941  사랑하는 어린이 여러분 일흔여덟번째 어린이날을 축하합니다. 오늘은 새천년의 첫 번째...
# 8942  알레만 니카라과 대통령 각하 내외분,그리고 내외 귀빈 여러분! 먼 여로를 마다치 않...

# %%
df.iloc[0]
# Out:
# division_number                                              1305368
# president                                                        박정희
# title                                            제5대 대통령 취임식 대통령 취임사
# date                                                      1963.12.17
# location                                                          국내
# kind                                                             취임사
# speech_text        \n\n\n단군성조가 천혜의 이 강토 위에 국기를 닦으신지 반만년, 연면히 이어온 ...
# Name: 5368, dtype: object

# %%
df.iloc[0:2,0:2]
# Out:
#       division_number president
# 5368          1305368       박정희
# 5369          1305369       박정희

# %%
df.iat[0, 1]
# Out:
# '박정희'

# %%
df[df.president == '노무현'].head()
# Out:
#       division_number president                      title        date  \
# 9379          1309347       노무현              제16 대 대통령 취임사  2003.02.25
# 9380          1309348       노무현        제16 대 대통령 취임 경축연 연설  2003.02.25
# 9381          1309349       노무현   제16 대통령 취임 축하 외빈을 위한 만찬사  2003.02.25
# 9382          1309350       노무현  학군사관후보생(ROTC) 제41기 임관식 치사  2003.02.28
# 9383          1309351       노무현        2·28민주의거 43주년 기념메시지  2003.02.28
#
#      location kind                                        speech_text
# 9379       국내  취임사  존경하는 국민 여러분.오늘 저는 대한민국의 제16대 대통령에 취임하기 위해 이 자리...
# 9380       국내  취임사  주한외교사절 여러분, 그리고 멀리서 오신 외빈 여러분,전두환 전 대통령과 3부요인을...
# 9381       국내  기념사  존경하는 폰 바이체커 전 독일 대통령,나카소네 야스히로 전 일본 총리, 모리 요시로...
# 9382       국내  기념사  친애하는 학군 제41기 신임장교 여러분,그리고 학부모와 내빈 여러분!신임장교 여러분...
# 9383       국내  기념사  43년 전 오늘, 대구는 자유당 정권의 독재에 맞서 분연히 일어섰습니다. 대구의 의...

# %%
df[df['president'].isin(['노무현', '박정희'])]
# Out:
#        division_number president                         title        date  \
# 5368           1305368       박정희           제5대 대통령 취임식 대통령 취임사  1963.12.17
# 5369           1305369       박정희                     국회 개회식 치사  1963.12.17
# 5370           1305370       박정희                        신년 메시지  1964.01.01
# 5371           1305371       박정희               신년 시무식에 즈음한 담화문        1964
# 5372           1305372       박정희                고급공무원에게 보내는 서신  1964.01.04
# ...                ...       ...                           ...         ...
# 10156          1310124       노무현                     2008년 신년사  2008.01.01
# 10157          1310125       노무현  울산 국민보도연맹사건 희생자 추모식에 보내는 메시지  2008.01.24
# 10158          1310126       노무현               정부조직개편안 관련 기자회견  2008.01.28
# 10362          1310330       박정희                          기자회견  1969.04.25
# 10468          1310436       박정희          달에 보내는 멧시지 (아폴로 11호)  1969.07.15
#
# ...

# %%
f_df = df[df['speech_text'].str.contains('계엄')]

# %%
n_df = f_df.groupby('president').size().reset_index(name='count')

# %%
n_df.sort_values(by='count', ascending=False)
# Out:
#   president  count
# 3       박정희     13
# 4       이승만     11
# 2       문재인     10
# 5       전두환     10
# 6       최규하      6
# 1       노태우      3
# 0       노무현      2
